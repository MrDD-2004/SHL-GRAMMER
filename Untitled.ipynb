# %%
# ===============================
# STEP 1: Imports and Setup
# ===============================
import numpy as np
np.complex = complex  # Patch for librosa compatibility

import os
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# ===============================
# STEP 2: Load Data
# ===============================
AUDIO_DIR = 'audios/train'  # Make sure this is the correct path
TRAIN_CSV = 'train.csv'
TEST_CSV = 'test.csv'
SUBMISSION_CSV = 'sample_submission.csv'

train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

print("✅ Train data shape:", train_df.shape)
print("✅ Test data shape:", test_df.shape)
print("✅ Train columns:", train_df.columns)

# ===============================
# STEP 3: Feature Extraction
# ===============================
def extract_features(filepath):
    try:
        y, sr = librosa.load(filepath, sr=16000)
        y, _ = librosa.effects.trim(y)

        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        chroma = librosa.feature.chroma_stft(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        rmse = librosa.feature.rms(y=y)

        features = np.hstack([
            np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
            np.mean(chroma, axis=1), np.std(chroma, axis=1),
            np.mean(zcr), np.std(zcr),
            np.mean(rmse), np.std(rmse)
        ])
        return features
    except Exception as e:
        print(f"❌ Error processing {filepath}: {e}")
        return np.zeros(60,)  # Adjust size based on feature vector

# ===============================
# STEP 4: Extract Training Features
# ===============================
X, y = [], []

for _, row in train_df.iterrows():
    file_path = os.path.join(AUDIO_DIR, row['filename'])
    if os.path.exists(file_path):
        features = extract_features(file_path)
        X.append(features)
        y.append(row['label'])
    else:
        print(f"❌ File not found: {file_path}")

X = np.array(X)
y = np.array(y)

# ===============================
# STEP 5: Preprocess and Split
# ===============================
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# ===============================
# STEP 6: Train Model
# ===============================
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# ==============================
# ==============================
# Evaluation
# ==============================
train_preds = model.predict(X_train)
val_preds = model.predict(X_val)

train_rmse = np.sqrt(mean_squared_error(y_train, train_preds))
val_rmse = np.sqrt(mean_squared_error(y_val, val_preds))

print(f"Train RMSE: {train_rmse:.4f}")
print(f"Validation RMSE: {val_rmse:.4f}")


# ===============================
# STEP 8: Predict Test Set
# ===============================
X_test = []
for _, row in test_df.iterrows():
    file_path = os.path.join(AUDIO_DIR, row['filename'])
    if os.path.exists(file_path):
        features = extract_features(file_path)
        X_test.append(features)
    else:
        print(f"❌ Test file not found: {file_path}")
        X_test.append(np.zeros_like(X[0]))

X_test = scaler.transform(np.array(X_test))
test_preds = model.predict(X_test)

# ===============================
# STEP 9: Create Submission File
# ===============================
submission = pd.read_csv(SUBMISSION_CSV)
submission['label'] = test_preds
submission.to_csv('submission.csv', index=False)

# ===============================
# STEP 10: Summary
# ===============================
print("\n✅ Training Complete!")
print(f"📁 Submission file saved as submission.csv")
# Out:
# ✅ Train data shape: (444, 2)
# ✅ Test data shape: (204, 1)
# ✅ Train columns: Index(['filename', 'label'], dtype='object')
# Train RMSE: 0.3272
# Validation RMSE: 0.8650
# ❌ Test file not found: audios/train\audio_804.wav
# ❌ Test file not found: audios/train\audio_1028.wav
# ❌ Test file not found: audios/train\audio_865.wav
# ❌ Test file not found: audios/train\audio_774.wav
# ❌ Test file not found: audios/train\audio_1138.wav
# ❌ Test file not found: audios/train\audio_278.wav
# ❌ Test file not found: audios/train\audio_1212.wav
# ❌ Test file not found: audios/train\audio_178.wav
# ❌ Test file not found: audios/train\audio_542.wav
# ❌ Test file not found: audios/train\audio_248.wav
# ❌ Test file not found: audios/train\audio_872.wav
# ❌ Test file not found: audios/train\audio_954.wav
# ❌ Test file not found: audios/train\audio_853.wav
# ❌ Test file not found: audios/train\audio_171.wav
# ❌ Test file not found: audios/train\audio_922.wav
# ❌ Test file not found: audios/train\audio_915.wav
# ❌ Test file not found: audios/train\audio_1220.wav
# ❌ Test file not found: audios/train\audio_1225.wav
# ❌ Test file not found: audios/train\audio_903.wav
# ❌ Test file not found: audios/train\audio_748.wav
# ❌ Test file not found: audios/train\audio_284.wav
# ❌ Test file not found: audios/train\audio_200.wav
# ❌ Test file not found: audios/train\audio_1255.wav
# ❌ Test file not found: audios/train\audio_1246.wav
# ❌ Test file not found: audios/train\audio_1102.wav
# ❌ Test file not found: audios/train\audio_1300.wav
# ❌ Test file not found: audios/train\audio_80.wav
# ❌ Test file not found: audios/train\audio_1041.wav
# ❌ Test file not found: audios/train\audio_256.wav
# ❌ Test file not found: audios/train\audio_328.wav
# ❌ Test file not found: audios/train\audio_301.wav
# ❌ Test file not found: audios/train\audio_938.wav
# ❌ Test file not found: audios/train\audio_1055.wav
# ❌ Test file not found: audios/train\audio_664.wav
# ❌ Test file not found: audios/train\audio_89.wav
# ❌ Test file not found: audios/train\audio_407.wav
# ❌ Test file not found: audios/train\audio_1025.wav
# ❌ Test file not found: audios/train\audio_72.wav
# ❌ Test file not found: audios/train\audio_1316.wav
# ❌ Test file not found: audios/train\audio_661.wav
# ❌ Test file not found: audios/train\audio_822.wav
# ❌ Test file not found: audios/train\audio_956.wav
# ❌ Test file not found: audios/train\audio_1329.wav
# ❌ Test file not found: audios/train\audio_1218.wav
# ❌ Test file not found: audios/train\audio_1286.wav
# ❌ Test file not found: audios/train\audio_1166.wav
# ❌ Test file not found: audios/train\audio_1231.wav
# ❌ Test file not found: audios/train\audio_501.wav
# ❌ Test file not found: audios/train\audio_188.wav
# ❌ Test file not found: audios/train\audio_746.wav
# ❌ Test file not found: audios/train\audio_218.wav
# ❌ Test file not found: audios/train\audio_168.wav
# ❌ Test file not found: audios/train\audio_689.wav
# ❌ Test file not found: audios/train\audio_234.wav
# ❌ Test file not found: audios/train\audio_670.wav
# ❌ Test file not found: audios/train\audio_241.wav
# ❌ Test file not found: audios/train\audio_1226.wav
# ❌ Test file not found: audios/train\audio_47.wav
# ❌ Test file not found: audios/train\audio_220.wav
# ❌ Test file not found: audios/train\audio_548.wav
# ❌ Test file not found: audios/train\audio_674.wav
# ❌ Test file not found: audios/train\audio_450.wav
# ❌ Test file not found: audios/train\audio_1326.wav
# ❌ Test file not found: audios/train\audio_128.wav
# ❌ Test file not found: audios/train\audio_430.wav
# ❌ Test file not found: audios/train\audio_376.wav
# ❌ Test file not found: audios/train\audio_502.wav
# ❌ Test file not found: audios/train\audio_67.wav
# ❌ Test file not found: audios/train\audio_1134.wav
# ❌ Test file not found: audios/train\audio_33.wav
# ❌ Test file not found: audios/train\audio_817.wav
# ❌ Test file not found: audios/train\audio_780.wav
# ❌ Test file not found: audios/train\audio_309.wav
# ❌ Test file not found: audios/train\audio_1039.wav
# ❌ Test file not found: audios/train\audio_765.wav
# ❌ Test file not found: audios/train\audio_353.wav
# ❌ Test file not found: audios/train\audio_940.wav
# ❌ Test file not found: audios/train\audio_1258.wav
# ❌ Test file not found: audios/train\audio_1170.wav
# ❌ Test file not found: audios/train\audio_1011.wav
# ❌ Test file not found: audios/train\audio_769.wav
# ❌ Test file not found: audios/train\audio_324.wav
# ❌ Test file not found: audios/train\audio_599.wav
# ❌ Test file not found: audios/train\audio_828.wav
# ❌ Test file not found: audios/train\audio_1294.wav
# ❌ Test file not found: audios/train\audio_585.wav
# ❌ Test file not found: audios/train\audio_904.wav
# ❌ Test file not found: audios/train\audio_1291.wav
# ❌ Test file not found: audios/train\audio_902.wav
# ❌ Test file not found: audios/train\audio_529.wav
# ❌ Test file not found: audios/train\audio_1006.wav
# ❌ Test file not found: audios/train\audio_827.wav
# ❌ Test file not found: audios/train\audio_909.wav
# ❌ Test file not found: audios/train\audio_947.wav
# ❌ Test file not found: audios/train\audio_952.wav
# ❌ Test file not found: audios/train\audio_647.wav
# ❌ Test file not found: audios/train\audio_841.wav
# ❌ Test file not found: audios/train\audio_261.wav
# ❌ Test file not found: audios/train\audio_14.wav
# ❌ Test file not found: audios/train\audio_681.wav
# ❌ Test file not found: audios/train\audio_818.wav
# ❌ Test file not found: audios/train\audio_1046.wav
# ❌ Test file not found: audios/train\audio_976.wav
# ❌ Test file not found: audios/train\audio_714.wav
# ❌ Test file not found: audios/train\audio_1207.wav
# ❌ Test file not found: audios/train\audio_1217.wav
# ❌ Test file not found: audios/train\audio_27.wav
# ❌ Test file not found: audios/train\audio_1131.wav
# ❌ Test file not found: audios/train\audio_682.wav
# ❌ Test file not found: audios/train\audio_1059.wav
# ❌ Test file not found: audios/train\audio_846.wav
# ❌ Test file not found: audios/train\audio_988.wav
# ❌ Test file not found: audios/train\audio_34.wav
# ❌ Test file not found: audios/train\audio_1186.wav
# ❌ Test file not found: audios/train\audio_1142.wav
# ❌ Test file not found: audios/train\audio_257.wav
# ❌ Test file not found: audios/train\audio_1092.wav
# ❌ Test file not found: audios/train\audio_117.wav
# ❌ Test file not found: audios/train\audio_744.wav
# ❌ Test file not found: audios/train\audio_449.wav
# ❌ Test file not found: audios/train\audio_1270.wav
# ❌ Test file not found: audios/train\audio_935.wav
# ❌ Test file not found: audios/train\audio_858.wav
# ❌ Test file not found: audios/train\audio_686.wav
# ❌ Test file not found: audios/train\audio_929.wav
# ❌ Test file not found: audios/train\audio_41.wav
# ❌ Test file not found: audios/train\audio_483.wav
# ❌ Test file not found: audios/train\audio_530.wav
# ❌ Test file not found: audios/train\audio_1158.wav
# ❌ Test file not found: audios/train\audio_130.wav
# ❌ Test file not found: audios/train\audio_962.wav
# ❌ Test file not found: audios/train\audio_505.wav
# ❌ Test file not found: audios/train\audio_966.wav
# ❌ Test file not found: audios/train\audio_989.wav
# ❌ Test file not found: audios/train\audio_464.wav
# ❌ Test file not found: audios/train\audio_1165.wav
# ❌ Test file not found: audios/train\audio_1200.wav
# ❌ Test file not found: audios/train\audio_554.wav
# ❌ Test file not found: audios/train\audio_481.wav
# ❌ Test file not found: audios/train\audio_245.wav
# ❌ Test file not found: audios/train\audio_453.wav
# ❌ Test file not found: audios/train\audio_1099.wav
# ❌ Test file not found: audios/train\audio_327.wav
# ❌ Test file not found: audios/train\audio_854.wav
# ❌ Test file not found: audios/train\audio_13.wav
# ❌ Test file not found: audios/train\audio_358.wav
# ❌ Test file not found: audios/train\audio_1104.wav
# ❌ Test file not found: audios/train\audio_236.wav
# ❌ Test file not found: audios/train\audio_373.wav
# ❌ Test file not found: audios/train\audio_701.wav
# ❌ Test file not found: audios/train\audio_612.wav
# ❌ Test file not found: audios/train\audio_161.wav
# ❌ Test file not found: audios/train\audio_472.wav
# ❌ Test file not found: audios/train\audio_967.wav
# ❌ Test file not found: audios/train\audio_267.wav
# ❌ Test file not found: audios/train\audio_709.wav
# ❌ Test file not found: audios/train\audio_534.wav
# ❌ Test file not found: audios/train\audio_298.wav
# ❌ Test file not found: audios/train\audio_995.wav
# ❌ Test file not found: audios/train\audio_24.wav
# ❌ Test file not found: audios/train\audio_1163.wav
# ❌ Test file not found: audios/train\audio_855.wav
# ❌ Test file not found: audios/train\audio_652.wav
# ❌ Test file not found: audios/train\audio_1069.wav
# ❌ Test file not found: audios/train\audio_415.wav
# ❌ Test file not found: audios/train\audio_1090.wav
# ❌ Test file not found: audios/train\audio_766.wav
# ❌ Test file not found: audios/train\audio_568.wav
# ❌ Test file not found: audios/train\audio_885.wav
# ❌ Test file not found: audios/train\audio_108.wav
# ❌ Test file not found: audios/train\audio_1179.wav
# ❌ Test file not found: audios/train\audio_377.wav
# ❌ Test file not found: audios/train\audio_390.wav
# ❌ Test file not found: audios/train\audio_692.wav
# ❌ Test file not found: audios/train\audio_508.wav
# ❌ Test file not found: audios/train\audio_357.wav
# ❌ Test file not found: audios/train\audio_273.wav
# ❌ Test file not found: audios/train\audio_1180.wav
# ❌ Test file not found: audios/train\audio_668.wav
# ❌ Test file not found: audios/train\audio_1187.wav
# ❌ Test file not found: audios/train\audio_452.wav
# ❌ Test file not found: audios/train\audio_335.wav
# ❌ Test file not found: audios/train\audio_268.wav
# ❌ Test file not found: audios/train\audio_330.wav
# ❌ Test file not found: audios/train\audio_637.wav
# ❌ Test file not found: audios/train\audio_339.wav
# ❌ Test file not found: audios/train\audio_1088.wav
# ❌ Test file not found: audios/train\audio_397.wav
# ❌ Test file not found: audios/train\audio_1136.wav
# ❌ Test file not found: audios/train\audio_153.wav
# ❌ Test file not found: audios/train\audio_99.wav
# ❌ Test file not found: audios/train\audio_249.wav
# ❌ Test file not found: audios/train\audio_590.wav
# ❌ Test file not found: audios/train\audio_57.wav
# ❌ Test file not found: audios/train\audio_749.wav
# ❌ Test file not found: audios/train\audio_978.wav
# ❌ Test file not found: audios/train\audio_981.wav
# ❌ Test file not found: audios/train\audio_563.wav
# ❌ Test file not found: audios/train\audio_531.wav
# ❌ Test file not found: audios/train\audio_787.wav
# ❌ Test file not found: audios/train\audio_1079.wav
# ❌ Test file not found: audios/train\audio_550.wav
# ❌ Test file not found: audios/train\audio_641.wav
# ❌ Test file not found: audios/train\audio_1001.wav
#
# ✅ Training Complete!
# 📁 Submission file saved as submission.csv
